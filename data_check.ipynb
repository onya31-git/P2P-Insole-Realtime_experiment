# %%
# (
#     './data/training_data/Skeleton/T004S003_skeleton.csv',
#     './data/20250518test4/InsoleSensor/3_final/T004S003_Insole_l.csv',
#     './data/20250518test4/InsoleSensor/3_final/T004S003_Insole_r.csv',
# ),(
#     './data/training_data/Skeleton/T004S004_skeleton.csv',
#     './data/20250518test4/InsoleSensor/3_final/T004S004_Insole_l.csv',
#     './data/20250518test4/InsoleSensor/3_final/T004S004_Insole_r.csv'
# )

# %%
import pandas as pd
import numpy as np

# %%
SKELETON_PATH = "./data/training_data/Skeleton/T004S003_skeleton.csv"
INSOLE_L_PATH = "./data/20250518test4/InsoleSensor/3_final/T004S003_Insole_l.csv"
INSOLE_R_PATH = "./data/20250518test4/InsoleSensor/3_final/T004S003_Insole_r.csv"

# %%
skeleton_data = pd.read_csv(SKELETON_PATH)
insole_l_data = pd.read_csv(INSOLE_L_PATH)
insole_r_data = pd.read_csv(INSOLE_R_PATH)

display(skeleton_data.info())
display(insole_l_data.info())
display(insole_r_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119704 entries, 1.305997 to 145.153641
# Data columns (total 63 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   X.1     119704 non-null  float64
#  1   Y.1     119704 non-null  float64
#  2   Z.1     119704 non-null  float64
#  3   X.3     119704 non-null  float64
#  4   Y.3     119704 non-null  float64
#  5   Z.3     119704 non-null  float64
#  6   X.5     119704 non-null  float64
#  7   Y.5     119704 non-null  float64
#  8   Z.5     119704 non-null  float64
#  9   X.7     119704 non-null  float64
#  10  Y.7     119704 non-null  float64
#  11  Z.7     119704 non-null  float64
#  12  X.9     119704 non-null  float64
#  13  Y.9     119704 non-null  float64
#  14  Z.9     119704 non-null  float64
#  15  X.11    119704 non-null  float64
#  16  Y.11    119704 non-null  float64
#  17  Z.11    119704 non-null  float64
#  18  X.13    119704 non-null  float64
#  19  Y.13    119704 non-null  float64
#  20  Z.13    119704 non-null  float64
#  21  X.15    119704 non-null  float64
#  22  Y.15    119704 non-null  float64
#  23  Z.15    119704 non-null  float64
#  24  X.17    119704 non-null  float64
#  25  Y.17    119704 non-null  float64
#  26  Z.17    119704 non-null  float64
#  27  X.19    119704 non-null  float64
#  28  Y.19    119704 non-null  float64
#  29  Z.19    119704 non-null  float64
#  30  X.21    119704 non-null  float64
#  31  Y.21    119704 non-null  float64
#  32  Z.21    119704 non-null  float64
#  33  X.23    119704 non-null  float64
#  34  Y.23    119704 non-null  float64
#  35  Z.23    119704 non-null  float64
#  36  X.25    119704 non-null  float64
#  37  Y.25    119704 non-null  float64
#  38  Z.25    119704 non-null  float64
#  39  X.27    119704 non-null  float64
#  40  Y.27    119704 non-null  float64
#  41  Z.27    119704 non-null  float64
#  42  X.29    119704 non-null  float64
#  43  Y.29    119704 non-null  float64
#  44  Z.29    119704 non-null  float64
#  45  X.31    119704 non-null  float64
#  46  Y.31    119704 non-null  float64
#  47  Z.31    119704 non-null  float64
#  48  X.33    119704 non-null  float64
#  49  Y.33    119704 non-null  float64
#  50  Z.33    119704 non-null  float64
#  51  X.35    119704 non-null  float64
#  52  Y.35    119704 non-null  float64
#  53  Z.35    119704 non-null  float64
#  54  X.37    119704 non-null  float64
#  55  Y.37    119704 non-null  float64
#  56  Z.37    119704 non-null  float64
#  57  X.39    119704 non-null  float64
#  58  Y.39    119704 non-null  float64
#  59  Z.39    119704 non-null  float64
#  60  X.41    119704 non-null  float64
#  61  Y.41    119704 non-null  float64
#  62  Z.41    5 non-null       float64
# dtypes: float64(63)
# memory usage: 58.4 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 
#  36  Gyro_y  119704 non-null  float64
#  37  Gyro_z  119704 non-null  float64
#  38  Acc_x   119704 non-null  float64
#  39  Acc_y   119704 non-null  float64
#  40  Acc_z   119704 non-null  float64
# dtypes: float64(41)
# memory usage: 37.4 MB
# None

# %%
display(skeleton_data.isnull().sum())
display(insole_l_data.isnull().sum())
display(insole_r_data.isnull().sum())
# Out:
# X.1          0
# Y.1          0
# Z.1          0
# X.3          0
# Y.3          0
#          ...
# Y.39         0
# Z.39         0
# X.41         0
# Y.41         0
# Z.41    119699
# Length: 63, dtype: int64
# P1        0
# P2        0
# P3        0
# P4        0
# P5        0
# P6        0
# P7        0
# P8        0
# P9        0
# P10       0
# P11       0
# P12       0
# P13       0
# P14       0
# P15       0
# P16       0
# P17       0
# P18       0
# P19       0
# P20       0
# P21       0
# P22       0
# P23       0
# P24       0
# P25       0
# P26       0
# P27       0
# P28       0
# P29       0
# P30       0
# P31       0
# P32       0
# P33       0
# P34       0
# P35       0
# Gyro_x    0
# Gyro_y    0
# Gyro_z    0
# Acc_x     0
# Acc_y     0
# Acc_z     0
# dtype: int64
# P1        0
# P2        0
# P3        0
# P4        0
# P5        0
# P6        0
# P7        0
# P8        0
# P9        0
# P10       0
# P11       0
# P12       0
# P13       0
# P14       0
# P15       0
# P16       0
# P17       0
# P18       0
# P19       0
# P20       0
# P21       0
# P22       0
# P23       0
# P24       0
# P25       0
# P26       0
# P27       0
# P28       0
# P29       0
# P30       0
# P31       0
# P32       0
# P33       0
# P34       0
# P35       0
# Gyro_x    0
# Gyro_y    0
# Gyro_z    0
# Acc_x     0
# Acc_y     0
# Acc_z     0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# ---------------------------------------------------------
# 設定：調査対象のファイルパス（train.pyで問題が疑われるデータ）
# ---------------------------------------------------------
target_pairs = [
    (
        # Case 1: T004S003
        './data/training_data/Skeleton/T004S003_skeleton.csv',
        './data/20250518test4/InsoleSensor/3_final/T004S003_Insole_l.csv',
        './data/20250518test4/InsoleSensor/3_final/T004S003_Insole_r.csv',
    ),
    (
        # Case 2: T004S004
        './data/training_data/Skeleton/T004S004_skeleton.csv',
        './data/20250518test4/InsoleSensor/3_final/T004S004_Insole_l.csv',
        './data/20250518test4/InsoleSensor/3_final/T004S004_Insole_r.csv'
    )
]

# ---------------------------------------------------------
# ユーティリティ関数
# ---------------------------------------------------------
def read_pressure_csv(path: str) -> pd.DataFrame:
    """train.pyと同様の読み込みロジック"""
    df = pd.read_csv(path, skiprows=1, low_memory=False)
    if "Timestamp" in df.columns:
        df = df.drop(columns=["Timestamp"])
    # 数値変換（エラー回避のためcoerce）
    df = df.apply(pd.to_numeric, errors='coerce')
    return df

def analyze_dataset(skeleton_path, left_path, right_path):
    print(f"\n{'='*60}")
    print(f"Analyzing Dataset: {Path(skeleton_path).stem}")
    print(f"{'='*60}")
    
    # 1. データ読み込み
    try:
        skel = pd.read_csv(skeleton_path)
        left = read_pressure_csv(left_path)
        right = read_pressure_csv(right_path)
    except FileNotFoundError as e:
        print(f"Error: File not found - {e}")
        return

    # データ長チェック
    min_len = min(len(skel), len(left), len(right))
    print(f"Data Lengths -> Skeleton: {len(skel)}, Left: {len(left)}, Right: {len(right)}")
    print(f"Effective Training Length (min): {min_len}")

    # 2. SkeletonデータのNaN詳細分析
    print(f"\n--- Skeleton Data Analysis ---")
    
    # 全体のNaN数
    total_nans = skel.isna().sum().sum()
    print(f"Total NaNs in Skeleton: {total_nans}")

    # 「全ての行がNaN」である列（マーカー）を探す
    # これが存在すると、ffill/bfillでも埋まらず、学習がクラッシュする原因になります
    all_nan_cols = skel.columns[skel.isna().all()].tolist()
    
    if all_nan_cols:
        print(f"\n[CRITICAL ERROR] Found columns that are ALL NaN (cannot be interpolated):")
        print(f"Count: {len(all_nan_cols)}")
        print(f"Columns: {all_nan_cols}")
    else:
        print("\n[OK] No columns are completely NaN.")

    # train.pyの補間ロジックをシミュレーション
    skel_filled = skel.fillna(method='bfill').fillna(method='ffill')
    remaining_nans = skel_filled.isna().sum().sum()
    
    if remaining_nans > 0:
        print(f"\n[WARNING] After ffill/bfill, {remaining_nans} NaNs still remain!")
        print("This confirms that simple interpolation is insufficient for this data.")
    else:
        print("\n[OK] ffill/bfill successfully removed all NaNs.")

    # 3. インソールデータのチェック
    print(f"\n--- Insole Data Analysis ---")
    print(f"Left Insole NaNs: {left.isna().sum().sum()}, Infs: {np.isinf(left).sum().sum()}")
    print(f"Right Insole NaNs: {right.isna().sum().sum()}, Infs: {np.isinf(right).sum().sum()}")

    # 4. 可視化 (NaNの位置をヒートマップで表示)
    if total_nans > 0:
        plt.figure(figsize=(12, 6))
        sns.heatmap(skel.isna(), cbar=False, cmap='viridis', yticklabels=False)
        plt.title(f"Missing Values Map (Yellow=NaN): {Path(skeleton_path).name}")
        plt.xlabel("Markers (Columns)")
        plt.ylabel("Time (Frames)")
        plt.show()

# ---------------------------------------------------------
# 実行
# ---------------------------------------------------------
for s_path, l_path, r_path in target_pairs:
    analyze_dataset(s_path, l_path, r_path)
# Out:
# ============================================================
# Analyzing Dataset: T004S003_skeleton
# ============================================================
# Data Lengths -> Skeleton: 119704, Left: 119703, Right: 119703
# Effective Training Length (min): 119703
#
# --- Skeleton Data Analysis ---
# Total NaNs in Skeleton: 119699
#
# [OK] No columns are completely NaN.
#
# [OK] ffill/bfill successfully removed all NaNs.
#
# --- Insole Data Analysis ---
# Left Insole NaNs: 0, Infs: 0
# Right Insole NaNs: 0, Infs: 0
# C:\Users\Atsuya_Watanabe\AppData\Local\Temp\ipykernel_40276\2705507311.py:75: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   skel_filled = skel.fillna(method='bfill').fillna(method='ffill')
# ============================================================
# Analyzing Dataset: T004S004_skeleton
# ============================================================
# Data Lengths -> Skeleton: 119528, Left: 119527, Right: 119527
# Effective Training Length (min): 119527
#
# --- Skeleton Data Analysis ---
# Total NaNs in Skeleton: 0
#
# [OK] No columns are completely NaN.
#
# [OK] ffill/bfill successfully removed all NaNs.
#
# --- Insole Data Analysis ---
# Left Insole NaNs: 0, Infs: 0
# Right Insole NaNs: 0, Infs: 0
# C:\Users\Atsuya_Watanabe\AppData\Local\Temp\ipykernel_40276\2705507311.py:75: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   skel_filled = skel.fillna(method='bfill').fillna(method='ffill')
